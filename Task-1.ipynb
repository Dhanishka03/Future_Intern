# %%
import pandas as pd
import numpy as np

# %%
df= pd.read_csv('titanic/train.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df['Age'].isnull().sum()
# Out:
# 177

# %%
df['Age'].fillna(df['Age'].median(), inplace=True)
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_16028\1933487976.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Age'].fillna(df['Age'].median(), inplace=True)

# %%
print("Missing values in Age after imputation:", df['Age'].isnull().sum())
# Out:
# Missing values in Age after imputation: 0

# %%
df.sample(10)
# Out:
#      PassengerId  Survived  Pclass  \
# 782          783         0       1
# 162          163         0       3
# 703          704         0       3
# 15            16         1       2
# 319          320         1       1
# 705          706         0       2
# 674          675         0       2
# 582          583         0       2
# 39            40         1       3
# 331          332         0       1
#
#                                                   Name     Sex   Age  SibSp  \
# 782                             Long, Mr. Milton Clyde    male  29.0      0
# 162                         Bengtsson, Mr. John Viktor    male  26.0      0
# 703                              Gallagher, Mr. Martin    male  25.0      0
# 15                    Hewlett, Mrs. (Mary D Kingcome)   female  55.0      0
# 319  Spedden, Mrs. Frederic Oakley (Margaretta Corn...  female  40.0      1
# 705     Morley, Mr. Henry Samuel ("Mr Henry Marshall")    male  39.0      0
# 674                         Watson, Mr. Ennis Hastings    male  28.0      0
# 582                         Downton, Mr. William James    male  54.0      0
# 39                         Nicola-Yarred, Miss. Jamila  female  14.0      1
# 331                                Partner, Mr. Austen    male  45.5      0
#
#      Parch  Ticket      Fare    Cabin Embarked
# 782      0  113501   30.0000       D6        S
# 162      0  347068    7.7750  Unknown        S
# 703      0   36864    7.7417  Unknown        Q
# 15       0  248706   16.0000  Unknown        S
# 319      1   16966  134.5000      E34        C
# 705      0  250655   26.0000  Unknown        S
# 674      0  239856    0.0000  Unknown        S
# 582      0   28403   26.0000  Unknown        S
# 39       0    2651   11.2417  Unknown        C
# 331      0  113043   28.5000     C124        S

# %%
df.tail()
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female  28.0      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age              0
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
print(df[['Cabin', 'Embarked']].isnull().sum())
# Out:
# Cabin       687
# Embarked      2
# dtype: int64

# %%
df['Cabin'].fillna('Unknown', inplace=True)
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_16028\876187935.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Cabin'].fillna('Unknown', inplace=True)

# %%
print("Missing values in Cabin after:", df['Cabin'].isnull().sum())
# Out:
# Missing values in Cabin after: 0

# %%
df.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Cabin          0
# Embarked       2
# dtype: int64

# %%
df.sample(10)
# Out:
#      PassengerId  Survived  Pclass  \
# 131          132         0       3
# 318          319         1       1
# 155          156         0       1
# 176          177         0       3
# 128          129         1       3
# 817          818         0       2
# 510          511         1       3
# 59            60         0       3
# 230          231         1       1
# 319          320         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 131                     Coelho, Mr. Domingos Fernandeo    male  20.0      0
# 318                           Wick, Miss. Mary Natalie  female  31.0      0
# 155                        Williams, Mr. Charles Duane    male  51.0      0
# 176                      Lefebre, Master. Henry Forbes    male  28.0      3
# 128                                  Peter, Miss. Anna  female  28.0      1
# 817                                 Mallet, Mr. Albert    male  31.0      1
# 510                           Daly, Mr. Eugene Patrick    male  29.0      0
# 59                  Goodwin, Master. William Frederick    male  11.0      5
# 230       Harris, Mrs. Henry Birkhardt (Irene Wallach)  female  35.0      1
# 319  Spedden, Mrs. Frederic Oakley (Margaretta Corn...  female  40.0      1
#
#      Parch              Ticket      Fare    Cabin Embarked
# 131      0  SOTON/O.Q. 3101307    7.0500  Unknown        S
# 318      2               36928  164.8667       C7        S
# 155      1            PC 17597   61.3792  Unknown        C
# 176      1                4133   25.4667  Unknown        S
# 128      1                2668   22.3583    F E69        C
# 817      1     S.C./PARIS 2079   37.0042  Unknown        C
# 510      0              382651    7.7500  Unknown        Q
# 59       2             CA 2144   46.9000  Unknown        S
# 230      0               36973   83.4750      C83        S
# 319      1               16966  134.5000      E34        C

# %%
df = df.dropna(subset=['Embarked'])

# %%
df.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Cabin          0
# Embarked       0
# dtype: int64

# %%
df['Sex'] = df['Sex'].replace({'male': 0, 'female': 1})

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name  Sex   Age  SibSp  Parch  \
# 0                            Braund, Mr. Owen Harris    0  22.0      1      0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...    1  38.0      1      0
# 2                             Heikkinen, Miss. Laina    1  26.0      0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)    1  35.0      1      0
# 4                           Allen, Mr. William Henry    0  35.0      0      0
#
#              Ticket     Fare    Cabin Embarked
# 0         A/5 21171   7.2500  Unknown        S
# 1          PC 17599  71.2833      C85        C
# 2  STON/O2. 3101282   7.9250  Unknown        S
# 3            113803  53.1000     C123        S
# 4            373450   8.0500  Unknown        S

# %%
df['Age']=df['Age'].astype(int)

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name  Sex  Age  SibSp  Parch  \
# 0                            Braund, Mr. Owen Harris    0   22      1      0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...    1   38      1      0
# 2                             Heikkinen, Miss. Laina    1   26      0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)    1   35      1      0
# 4                           Allen, Mr. William Henry    0   35      0      0
#
#              Ticket     Fare    Cabin Embarked
# 0         A/5 21171   7.2500  Unknown        S
# 1          PC 17599  71.2833      C85        C
# 2  STON/O2. 3101282   7.9250  Unknown        S
# 3            113803  53.1000     C123        S
# 4            373450   8.0500  Unknown        S
